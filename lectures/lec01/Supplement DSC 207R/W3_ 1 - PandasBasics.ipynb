# %%
import pandas as pd

# %%
names = ["Nikhil", "Shivangi", "Hansin"]
names

# %%
names_series = pd.Series(names)
names_series

# %%
office_hours_series = pd.Series([4, 2, 2])
office_hours_series

# %%
df = pd.DataFrame({"name": names_series, "office_hours": office_hours_series})
df

# %%
df["name"]

# %%
df["office_hours"]

# %%
df

# %%
boolean_series = pd.Series([True, False, True])
boolean_series

# %%
df[boolean_series]

# %%
df["office_hours"]

# %%
df["office_hours"] >= 3

# %%
df

# %%
hours_greater_equal_three = (df["office_hours"] >= 3)
hours_greater_equal_three

# %%
df[hours_greater_equal_three]

# %%
df

# %%
df_hours_greater_equal_three = df[hours_greater_equal_three]
df_hours_greater_equal_three

# %%
df["office_hours"] <= 2

# %%
df[df["office_hours"] <= 2]

# %%
df_hours_less_than_equal_to_two = df[df["office_hours"] <= 2]
df_hours_less_than_equal_to_two

# %%
df
