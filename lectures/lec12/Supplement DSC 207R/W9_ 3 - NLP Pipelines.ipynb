# %% [markdown]
# <h2 align="center">Spacy Language Processing Pipelines Tutorial</h2>

# %% [markdown]
# <h3>Blank nlp pipeline</h3>

# %%
import spacy

nlp = spacy.blank("en")

doc = nlp("Vinodh ate donuts for $20. Then he said I can do this all day.")

for token in doc:
    print(token)
# Out:
# Vinodh
# ate
# donuts
# for
# $
# 20
# .
# Then
# he
# said
# I
# can
# do
# this
# all
# day
# .

# %% [markdown]
# Pipeline is something that starts with a Tokenizer component in a dotted rectange below. You can see there is nothing there hence the blank pipeline

# %% [markdown]
# <center><img height=400 width=600 src="https://drive.google.com/uc?export=view&id=1JWeTvpHkvJ5Cm87hPoVGX64IIZUknuFJ"/></center>

# %%
nlp.pipe_names
# Out:
# []

# %% [markdown]
# nlp.pipe_names is empty array indicating no components in the pipeline. Pipeline is something that starts with a tokenizer

# %% [markdown]
# More general diagram for nlp pipeline may look something like below

# %% [markdown]
# <center><img height=400 width=600 src="https://drive.google.com/uc?export=view&id=1GxjcvKv_46No7Vx6jRU9dh0ObEYjjLOa"/></center>

# %% [markdown]
# <h3>Download trained pipeline</h3>

# %% [markdown]
# To download trained pipeline use a command such as,
#
# `python -m spacy download en_core_web_sm`
#
# This downloads the small (sm) pipeline for english language
#
# Further instructions on : https://spacy.io/usage/models#quickstart

# %%
nlp = spacy.load("en_core_web_sm")
nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
nlp.pipeline
# Out:
# [('tok2vec', <spacy.pipeline.tok2vec.Tok2Vec at 0x7e72c1a041c0>),
#  ('tagger', <spacy.pipeline.tagger.Tagger at 0x7e72c1a04ee0>),
#  ('parser', <spacy.pipeline.dep_parser.DependencyParser at 0x7e72c60453f0>),
#  ('attribute_ruler',
#   <spacy.pipeline.attributeruler.AttributeRuler at 0x7e72c55e1200>),
#  ('lemmatizer',
#   <spacy.lang.en.lemmatizer.EnglishLemmatizer at 0x7e72c5641b00>),
#  ('ner', <spacy.pipeline.ner.EntityRecognizer at 0x7e72c6045380>)]

# %% [markdown]
# sm in en_core_web_sm means small. There are other models available as well such as medium, large etc. Check this: https://spacy.io/usage/models#quickstart

# %%
doc = nlp("Vinodh ate donuts for $20. Then he said I can do this all day.")

for token in doc:
    print(token, " | ", spacy.explain(token.pos_), " | ",token.pos, " | ", token.lemma_)
# Out:
# Vinodh  |  proper noun  |  96  |  Vinodh
# ate  |  verb  |  100  |  eat
# donuts  |  noun  |  92  |  donut
# for  |  adposition  |  85  |  for
# $  |  symbol  |  99  |  $
# 20  |  numeral  |  93  |  20
# .  |  punctuation  |  97  |  .
# Then  |  adverb  |  86  |  then
# he  |  pronoun  |  95  |  he
# said  |  verb  |  100  |  say
# I  |  pronoun  |  95  |  I
# can  |  auxiliary  |  87  |  can
# do  |  verb  |  100  |  do
# this  |  pronoun  |  95  |  this
# all  |  determiner  |  90  |  all
# day  |  noun  |  92  |  day
# .  |  punctuation  |  97  |  .

# %% [markdown]
# **Run same code above with a blank pipeline and check what output you see?**

# %% [markdown]
# <h3>Named Entity Recognition</h3>

# %%
doc = nlp("Tesla Inc acquired Twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Tesla Inc ORG
# Twitter PRODUCT
# $45 billion MONEY

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tesla Inc
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  acquired
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Twitter
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     $45 billion
# ...

# %%
doc = nlp("Six years after the first Model 3 Performance deliveries, we are launching the new Model 3 Performance: a highly differentiated performance trim that leverages Tesla’s latest manufacturing and engineering capabilities to create what we consider to be a perfect, high-performance daily driver.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Six years DATE
# first ORDINAL
# Model 3 Performance PRODUCT
# Model 3 Performance PRODUCT
# Tesla ORG
# daily DATE

# %%
from spacy import displacy

displacy.render(doc, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Six years
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  after the
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Model 3 Performance
# ...

# %% [markdown]
# <h3>Adding a component to a blank pipeline</h3>

# %%
source_nlp = spacy.load("en_core_web_sm")

nlp = spacy.blank("en")
nlp.add_pipe("ner", source=source_nlp)
nlp.pipe_names
# Out:
# ['ner']

# %%
doc = nlp("Tesla Inc acquired Twitter for $45 billion")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Tesla Inc ORG
# Twitter PRODUCT
# $45 billion MONEY

# %% [markdown]
# In below image you can see sentecizer component in the pipeline

# %% [markdown]
# <center><img height=400 width=600 src="https://drive.google.com/uc?export=view&id=1Gxk0Wtfzjd5-sY5As1mRkIUmpiIyPdDy"/></center>

# %% [markdown]
# <h3>Further reading</h3>

# %% [markdown]
# https://spacy.io/usage/processing-pipelines#pipelines

# %% [markdown]
# # Acknowledgements
# This NLP tutorial was adapted and modified from Dhaval Patel's NLP tutorials.
